# %% [markdown]
# <h1><b>Conversacion Gemini</b></h1>

# %% [markdown]
# Ejercicios

# %% [markdown]
# https://aistudio.google.com/

# %% [markdown]
# <h2> Salida estructurada </h2>
# Ir a: https://aistudio.google.com/
# seleccionar: Structured output
#
# Analiza el siguiente párrafo y devuélveme un resumen estructurado en formato JSON. Quiero que identifiques:
#
# - personas mencionadas,
# - organizaciones,
# - ubicaciones,
# - y temas principales.
#
# Texto:
# "En abril de 2024, Sundar Pichai, CEO de Google, anunció en una conferencia en San Francisco que la compañía lanzaría nuevas funciones de inteligencia artificial en Gmail y Google Docs."

# %% [markdown]
# Seleccionar: Code Execution
#
# Corre este código Python:
# ```python
# import datetime
#
# now = datetime.datetime.now()
# print("Fecha y hora actual:", now)
# ```
