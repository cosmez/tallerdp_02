# %% [markdown]
# # Estructura interna de un Modelo de lenguaje

# %% [markdown]
# Ejercicios

# %% [markdown]
# <h2>Ejemplo interactivo de transformers</h2>
# https://poloclub.github.io/transformer-explainer/

# %% [markdown]
# ## Tokens

# %%
# %pip install tiktoken

# %%
#Libreria utilizada para el ejercicio de tokens
import tiktoken

# %% [markdown]
# ### Ejercicio para conteo de tokens

# %% [markdown]
# Elegimos el modelo gpt-3.5-turbo:

# %%
encoding = tiktoken.encoding_for_model("gpt-4o")
#encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

def analizar_texto(texto):
    tokens = encoding.encode(texto)
    print(f"\nTexto original: {texto}")
    print(f"Número de tokens: {len(tokens)}")
    print("Tokens individuales:")
    for i, token in enumerate(tokens):
        decoded = encoding.decode([token])
        print(f"{i+1:02d} → Token ID: {token} → Texto: '{decoded}'")

# %%
texto_usuario = input("Escribe una frase para analizar: ")
analizar_texto(texto_usuario)

# %% [markdown]
# Ejercicio
# Regresa nuevamente a la celda de eleccion del modelo:
# 1. Comenta con el simbolo "#" el encoding de gtp-3.5-turbo
# 2. Descomenta el encoding de gpt-4o
# 3. Corre de nuevo las celdas de la funcion analizar_texto y la de la frase para analizar
# 4. Escribe la misma frase que utilizaste
# 3. Analiza que diferencia vez

# %% [markdown]
# ### Ejercicio Escribe una frase para analizar el numero de tokens

# %%
tokenscount = encoding.encode("")
print("Numero de tokens: ", len(tokenscount))

# %% [markdown]
# Online tokenizer: https://platform.openai.com/tokenizer
